# %% [markdown]
# # Chapter VII: Derivatives

# %%
import matplotlib.pyplot as plt
import numpy as np
def f(x):
    return 2*x

# %%
x = np.array(range(5))
y = f(x)
print(x)
print(y)
# Out:
# [0 1 2 3 4]
# [0 2 4 6 8]

# %%
plt.plot(x, y)
plt.show()

# %%
print((y[1]-y[0]) / (x[1]-x[0]))
# Out:
# 2.0
