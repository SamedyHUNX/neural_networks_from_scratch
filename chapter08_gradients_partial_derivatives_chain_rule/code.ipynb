# %% [markdown]
# # Chapter VIII: Gradients, Partial Derivatives, and the Chain Rule

# %% [markdown]
# ![Screenshot 2025-10-21 at 11.14.33 at night.png](attachment:d4278643-a7c5-4935-8300-931f4c330065.png)

# %% [markdown]
# ![Screenshot 2025-10-21 at 11.14.56 at night.png](attachment:abe75dbc-a899-4dbc-99c8-22e0a1c96890.png)

# %% [markdown]
# ![Screenshot 2025-10-21 at 11.15.18 at night.png](attachment:8ff9319c-7e5b-4434-a536-73d6664c96e7.png)
